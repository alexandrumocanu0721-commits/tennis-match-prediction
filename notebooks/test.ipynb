# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2
# ----> 3 from tennis_pipeline import (
#       4     path_processed_backtest_predictions_csv
#       5 )
#
# ModuleNotFoundError: No module named 'tennis_pipeline'

# %%
df = pd.read_csv("../data/processed/backtest_predictions.csv")

# %%
df['actual_winner'].value_counts()
# Out:
# actual_winner
# 0    594
# 1    575
# Name: count, dtype: int64

# %%
df['predicted_prob_a'].mean()
# Out:
# np.float64(0.5288949081103507)

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/backtest/real_2026_odds.csv", sep=";")

# %%
df.head()
# Out:
#    ATP  Location              Tournament        Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International  04.01.2026  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International  04.01.2026  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
#
#        Round  Best of        Winner  ... B365W  B365L   PSW   PSL  MaxW  MaxL  \
# 0  1st Round        3     Tiafoe F.  ...  1,44   2,75  1,52   2,7  1,53  2,95
# 1  1st Round        3       Tien L.  ...  1,14    5,5   1,2  5,21  1,18   5,5
# 2  1st Round        3      Korda S.  ...   1,5   2,63  1,54  2,64  1,52  2,75
# 3  1st Round        3  Michelsen A.  ...  1,73    2,1  1,73  2,22   1,8   2,2
# 4  1st Round        3    Lehecka J.  ...   1,5   2,63  1,52  2,71  1,57  2,75
#
#    AvgW  AvgL  BFEW  BFEL
# ...

# %%
df['Comment'].value_counts()
# Out:
# Comment
# Completed    984
# Retired       25
# Walkover       7
# Name: count, dtype: int64

# %%
df = df[~df['Comment'].str.contains("Retired", na=False)]

# %%
df = df[~df['Comment'].str.contains("Walkover", na=False)]

# %%
df['Comment'].value_counts()
# Out:
# Comment
# Completed    984
# Name: count, dtype: int64

# %%
df = df.dropna(subset=['BFEW'])

# %%
df = df.dropna(subset=['BFEL'])

# %%
df['Comment'].value_counts()
# Out:
# Comment
# Completed    890
# Name: count, dtype: int64

# %%
df.to_csv("real_2026_odds.csv", index=False)

# %%
df['BFEW'].value_counts()
# Out:
# BFEW
# 1,44    16
# 1,28    14
# 1,38    14
# 1,29    14
# 1,35    12
#         ..
# 2,74     1
# 9,6      1
# 15       1
# 2,96     1
# 3,9      1
# Name: count, Length: 179, dtype: int64

# %%
print(df['BFEW'].dtype)
# Out:
# str

# %%
df["BFEW"] = df["BFEW"].str.replace(",", ".").astype(float)
df["BFEL"] = df["BFEL"].str.replace(",", ".").astype(float)

# %%
df.to_csv("real_2026_odds.csv", index=False)

# %%
df['BFEW'].mean()
# Out:
# np.float64(1.9300786516853932)

# %%
df['BFEL'].mean()
# Out:
# np.float64(4.177685393258427)

# %%
df = pd.read_csv("../data/backtest/real_2026_odds.csv")
df.head()
# Out:
#    ATP  Location              Tournament        Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International  04.01.2026  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International  04.01.2026  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
#
#        Round  Best of        Winner  ... B365W  B365L   PSW   PSL  MaxW  MaxL  \
# 0  1st Round        3     Tiafoe F.  ...  1,44   2,75  1,52   2,7  1,53  2,95
# 1  1st Round        3       Tien L.  ...  1,14    5,5   1,2  5,21  1,18   5,5
# 2  1st Round        3      Korda S.  ...   1,5   2,63  1,54  2,64  1,52  2,75
# 3  1st Round        3  Michelsen A.  ...  1,73    2,1  1,73  2,22   1,8   2,2
# 4  1st Round        3    Lehecka J.  ...   1,5   2,63  1,52  2,71  1,57  2,75
#
#    AvgW  AvgL  BFEW  BFEL
# ...

# %%
df["PSW"] = df["PSW"].str.replace(",", ".").astype(float)
df["PSL"] = df["PSL"].str.replace(",", ".").astype(float)
df["MaxW"] = df["MaxW"].str.replace(",", ".").astype(float)
df["MaxL"] = df["MaxL"].str.replace(",", ".").astype(float)

# %%
df.head()
# Out:
#    ATP  Location              Tournament        Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International  04.01.2026  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International  04.01.2026  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International  05.01.2026  ATP250  Outdoor    Hard
#
#        Round  Best of        Winner  ... B365W  B365L   PSW   PSL  MaxW  MaxL  \
# 0  1st Round        3     Tiafoe F.  ...  1,44   2,75  1.52  2.70  1.53  2.95
# 1  1st Round        3       Tien L.  ...  1,14    5,5  1.20  5.21  1.18  5.50
# 2  1st Round        3      Korda S.  ...   1,5   2,63  1.54  2.64  1.52  2.75
# 3  1st Round        3  Michelsen A.  ...  1,73    2,1  1.73  2.22  1.80  2.20
# 4  1st Round        3    Lehecka J.  ...   1,5   2,63  1.52  2.71  1.57  2.75
#
#    AvgW  AvgL  BFEW  BFEL
# ...

# %%
df.to_csv("real_2026_odds.csv", index=False)
